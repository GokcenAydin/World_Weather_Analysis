# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy
import random

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 751

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
    
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"] 
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                         "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | severo-kurilsk
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | san luis
# Processing Record 5 of Set 1 | puerto ayora
# Processing Record 6 of Set 1 | bengkulu
# Processing Record 7 of Set 1 | kyren
# Processing Record 8 of Set 1 | meadow lake
# Processing Record 9 of Set 1 | port-gentil
# Processing Record 10 of Set 1 | vaini
# Processing Record 11 of Set 1 | dikson
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | hithadhoo
# Processing Record 14 of Set 1 | catuday
# Processing Record 15 of Set 1 | werda
# Processing Record 16 of Set 1 | jamestown
# Processing Record 17 of Set 1 | tabas
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | ostrovnoy
# Processing Record 20 of Set 1 | dakar
# Processing Record 21 of Set 1 | san quintin
# Processing Record 22 of Set 1 | kapaa
# Processing Record 23 of Set 1 | kintampo
# Processing Record 24 of Set 1 | lagoa
# Processing Record 25 of Set 1 | kelo
# Processing Record 26 of Set 1 | new norfolk
# Processing Record 27 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 1 | numi
# City not found. Skipping...
# Processing Record 29 of Set 1 | saldanha
# Processing Record 30 of Set 1 | kavaratti
# Processing Record 31 of Set 1 | marsassoum
# Processing Record 32 of Set 1 | plavsk
# Processing Record 33 of Set 1 | tuy hoa
# Processing Record 34 of Set 1 | pitimbu
# Processing Record 35 of Set 1 | kloulklubed
# Processing Record 36 of Set 1 | le port
# Processing Record 37 of Set 1 | progreso
# Processing Record 38 of Set 1 | chuy
# Processing Record 39 of Set 1 | lorengau
# Processing Record 40 of Set 1 | neiafu
# Processing Record 41 of Set 1 | avarua
# Processing Record 42 of Set 1 | hermanus
# Processing Record 43 of Set 1 | sola
# Processing Record 44 of Set 1 | tiksi
# Processing Record 45 of Set 1 | punta arenas
# Processing Record 46 of Set 1 | jiayuguan
# Processing Record 47 of Set 1 | atuona
# Processing Record 48 of Set 1 | geraldton
# Processing Record 49 of Set 1 | kansas city
# Processing Record 50 of Set 1 | taoudenni
# Processing Record 1 of Set 2 | kindu
# Processing Record 2 of Set 2 | rio grande
# Processing Record 3 of Set 2 | tasiilaq
# Processing Record 4 of Set 2 | lavrentiya
# Processing Record 5 of Set 2 | abalak
# Processing Record 6 of Set 2 | yellowknife
# Processing Record 7 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 8 of Set 2 | moose factory
# Processing Record 9 of Set 2 | constitucion
# Processing Record 10 of Set 2 | cabo san lucas
# Processing Record 11 of Set 2 | tuktoyaktuk
# Processing Record 12 of Set 2 | sokolka
# Processing Record 13 of Set 2 | atasu
# Processing Record 14 of Set 2 | torbay
# Processing Record 15 of Set 2 | polis
# Processing Record 16 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 2 | nanortalik
# Processing Record 18 of Set 2 | thompson
# Processing Record 19 of Set 2 | kirkwood
# Processing Record 20 of Set 2 | qaanaaq
# Processing Record 21 of Set 2 | cape town
# Processing Record 22 of Set 2 | esperance
# Processing Record 23 of Set 2 | salalah
# Processing Record 24 of Set 2 | viligili
# City not found. Skipping...
# Processing Record 25 of Set 2 | mar del plata
# Processing Record 26 of Set 2 | east london
# Processing Record 27 of Set 2 | nanakuli
# Processing Record 28 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 29 of Set 2 | dunedin
# Processing Record 30 of Set 2 | kanye
# Processing Record 31 of Set 2 | manturovo
# Processing Record 32 of Set 2 | mayumba
# Processing Record 33 of Set 2 | ostrzeszow
# Processing Record 34 of Set 2 | bellevue
# Processing Record 35 of Set 2 | sao jose da coroa grande
# Processing Record 36 of Set 2 | clyde river
# Processing Record 37 of Set 2 | iqaluit
# Processing Record 38 of Set 2 | hargeysa
# Processing Record 39 of Set 2 | hofn
# Processing Record 40 of Set 2 | hobart
# Processing Record 41 of Set 2 | buluang
# Processing Record 42 of Set 2 | lebu
# Processing Record 43 of Set 2 | ribeira grande
# Processing Record 44 of Set 2 | dingle
# Processing Record 45 of Set 2 | cherskiy
# Processing Record 46 of Set 2 | hervey bay
# Processing Record 47 of Set 2 | tura
# Processing Record 48 of Set 2 | bluff
# Processing Record 49 of Set 2 | sinnamary
# Processing Record 50 of Set 2 | port blair
# Processing Record 1 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 3 | busselton
# Processing Record 4 of Set 3 | barrow
# Processing Record 5 of Set 3 | oranjemund
# Processing Record 6 of Set 3 | georgetown
# Processing Record 7 of Set 3 | tiznit
# Processing Record 8 of Set 3 | chyhyryn
# Processing Record 9 of Set 3 | kushmurun
# Processing Record 10 of Set 3 | blagoyevo
# Processing Record 11 of Set 3 | baranain
# Processing Record 12 of Set 3 | upernavik
# Processing Record 13 of Set 3 | port elizabeth
# Processing Record 14 of Set 3 | port alfred
# Processing Record 15 of Set 3 | hualmay
# Processing Record 16 of Set 3 | mitzic
# Processing Record 17 of Set 3 | castro
# Processing Record 18 of Set 3 | hilo
# Processing Record 19 of Set 3 | talaya
# Processing Record 20 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 3 | isangel
# Processing Record 22 of Set 3 | bocos
# Processing Record 23 of Set 3 | farah
# Processing Record 24 of Set 3 | portoferraio
# Processing Record 25 of Set 3 | atar
# Processing Record 26 of Set 3 | falealupo
# City not found. Skipping...
# Processing Record 27 of Set 3 | fare
# Processing Record 28 of Set 3 | yumen
# Processing Record 29 of Set 3 | kismayo
# Processing Record 30 of Set 3 | portland
# Processing Record 31 of Set 3 | bahia de caraquez
# Processing Record 32 of Set 3 | najran
# Processing Record 33 of Set 3 | bandarbeyla
# Processing Record 34 of Set 3 | carlsbad
# Processing Record 35 of Set 3 | buraydah
# Processing Record 36 of Set 3 | erenhot
# Processing Record 37 of Set 3 | motygino
# Processing Record 38 of Set 3 | tual
# Processing Record 39 of Set 3 | mogzon
# Processing Record 40 of Set 3 | zhitikara
# City not found. Skipping...
# Processing Record 41 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 42 of Set 3 | talnakh
# Processing Record 43 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 3 | saskylakh
# Processing Record 45 of Set 3 | ardmore
# Processing Record 46 of Set 3 | nikolskoye
# Processing Record 47 of Set 3 | pilao arcado
# City not found. Skipping...
# Processing Record 48 of Set 3 | icatu
# Processing Record 49 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 3 | berlevag
# Processing Record 1 of Set 4 | baherden
# Processing Record 2 of Set 4 | airai
# Processing Record 3 of Set 4 | ahmadnagar
# Processing Record 4 of Set 4 | karratha
# Processing Record 5 of Set 4 | gimli
# Processing Record 6 of Set 4 | omboue
# Processing Record 7 of Set 4 | hami
# Processing Record 8 of Set 4 | khatanga
# Processing Record 9 of Set 4 | pishin
# Processing Record 10 of Set 4 | topolobampo
# Processing Record 11 of Set 4 | seymchan
# Processing Record 12 of Set 4 | mandalgovi
# Processing Record 13 of Set 4 | bethany
# Processing Record 14 of Set 4 | saint-philippe
# Processing Record 15 of Set 4 | magaria
# Processing Record 16 of Set 4 | san patricio
# Processing Record 17 of Set 4 | atambua
# Processing Record 18 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 4 | deputatskiy
# Processing Record 20 of Set 4 | nome
# Processing Record 21 of Set 4 | acajutla
# Processing Record 22 of Set 4 | kodiak
# Processing Record 23 of Set 4 | harper
# Processing Record 24 of Set 4 | kashi
# Processing Record 25 of Set 4 | faanui
# Processing Record 26 of Set 4 | sao joao da barra
# Processing Record 27 of Set 4 | los andes
# Processing Record 28 of Set 4 | pochutla
# Processing Record 29 of Set 4 | puerto penasco
# Processing Record 30 of Set 4 | manzil tamim
# City not found. Skipping...
# Processing Record 31 of Set 4 | mildura
# Processing Record 32 of Set 4 | sambava
# Processing Record 33 of Set 4 | mount isa
# Processing Record 34 of Set 4 | pangody
# Processing Record 35 of Set 4 | maumere
# Processing Record 36 of Set 4 | inhambane
# Processing Record 37 of Set 4 | narsaq
# Processing Record 38 of Set 4 | gizo
# Processing Record 39 of Set 4 | mayo
# Processing Record 40 of Set 4 | victoria
# Processing Record 41 of Set 4 | winnemucca
# Processing Record 42 of Set 4 | oksovskiy
# Processing Record 43 of Set 4 | morondava
# Processing Record 44 of Set 4 | pevek
# Processing Record 45 of Set 4 | kita
# Processing Record 46 of Set 4 | arraial do cabo
# Processing Record 47 of Set 4 | villaviciosa
# Processing Record 48 of Set 4 | mutsamudu
# City not found. Skipping...
# Processing Record 49 of Set 4 | galiwinku
# City not found. Skipping...
# Processing Record 50 of Set 4 | naze
# Processing Record 1 of Set 5 | ballina
# Processing Record 2 of Set 5 | yinchuan
# Processing Record 3 of Set 5 | xadani
# City not found. Skipping...
# Processing Record 4 of Set 5 | podor
# Processing Record 5 of Set 5 | verkhnyaya inta
# Processing Record 6 of Set 5 | mahebourg
# Processing Record 7 of Set 5 | kahului
# Processing Record 8 of Set 5 | richards bay
# Processing Record 9 of Set 5 | gat
# Processing Record 10 of Set 5 | bhalki
# Processing Record 11 of Set 5 | vao
# Processing Record 12 of Set 5 | pangnirtung
# Processing Record 13 of Set 5 | gamba
# Processing Record 14 of Set 5 | petropavlovka
# Processing Record 15 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 16 of Set 5 | alice springs
# Processing Record 17 of Set 5 | sitka
# Processing Record 18 of Set 5 | baruun-urt
# Processing Record 19 of Set 5 | tlahualilo
# City not found. Skipping...
# Processing Record 20 of Set 5 | paamiut
# Processing Record 21 of Set 5 | mahaicony
# City not found. Skipping...
# Processing Record 22 of Set 5 | hirara
# Processing Record 23 of Set 5 | pimentel
# Processing Record 24 of Set 5 | codrington
# Processing Record 25 of Set 5 | wasilla
# Processing Record 26 of Set 5 | port hueneme
# Processing Record 27 of Set 5 | sao simao
# Processing Record 28 of Set 5 | ariquemes
# Processing Record 29 of Set 5 | zhezkazgan
# Processing Record 30 of Set 5 | faya
# Processing Record 31 of Set 5 | estacion coahuila
# Processing Record 32 of Set 5 | muli
# Processing Record 33 of Set 5 | zapolyarnyy
# Processing Record 34 of Set 5 | along
# Processing Record 35 of Set 5 | bredasdorp
# Processing Record 36 of Set 5 | tuatapere
# Processing Record 37 of Set 5 | carnarvon
# Processing Record 38 of Set 5 | tabou
# Processing Record 39 of Set 5 | trairi
# Processing Record 40 of Set 5 | cooma
# Processing Record 41 of Set 5 | yuli
# Processing Record 42 of Set 5 | los llanos de aridane
# Processing Record 43 of Set 5 | mortka
# Processing Record 44 of Set 5 | seoul
# Processing Record 45 of Set 5 | kruisfontein
# Processing Record 46 of Set 5 | palaiokhora
# City not found. Skipping...
# Processing Record 47 of Set 5 | kaitangata
# Processing Record 48 of Set 5 | verkhoyansk
# Processing Record 49 of Set 5 | hibbing
# Processing Record 50 of Set 5 | rorvik
# Processing Record 1 of Set 6 | comodoro rivadavia
# Processing Record 2 of Set 6 | hauterive
# Processing Record 3 of Set 6 | aripuana
# Processing Record 4 of Set 6 | belyy
# Processing Record 5 of Set 6 | labuhan
# Processing Record 6 of Set 6 | hobyo
# Processing Record 7 of Set 6 | katsuura
# Processing Record 8 of Set 6 | arlit
# Processing Record 9 of Set 6 | norman wells
# Processing Record 10 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 6 | hasaki
# Processing Record 12 of Set 6 | ravar
# Processing Record 13 of Set 6 | sorong
# Processing Record 14 of Set 6 | nantucket
# Processing Record 15 of Set 6 | caratinga
# Processing Record 16 of Set 6 | praia
# Processing Record 17 of Set 6 | conakry
# Processing Record 18 of Set 6 | kaspiyskiy
# Processing Record 19 of Set 6 | beringovskiy
# Processing Record 20 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 6 | chapais
# Processing Record 22 of Set 6 | laguna
# Processing Record 23 of Set 6 | resistencia
# Processing Record 24 of Set 6 | adrar
# Processing Record 25 of Set 6 | waipawa
# Processing Record 26 of Set 6 | genhe
# Processing Record 27 of Set 6 | avera
# Processing Record 28 of Set 6 | souillac
# Processing Record 29 of Set 6 | havre-saint-pierre
# Processing Record 30 of Set 6 | seminole
# Processing Record 31 of Set 6 | meulaboh
# Processing Record 32 of Set 6 | homer
# Processing Record 33 of Set 6 | talant
# Processing Record 34 of Set 6 | usinsk
# Processing Record 35 of Set 6 | dera ghazi khan
# Processing Record 36 of Set 6 | tevaitoa
# Processing Record 37 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 6 | tautira
# Processing Record 39 of Set 6 | oristano
# Processing Record 40 of Set 6 | gejiu
# Processing Record 41 of Set 6 | zwickau
# Processing Record 42 of Set 6 | greenville
# Processing Record 43 of Set 6 | provideniya
# Processing Record 44 of Set 6 | daru
# Processing Record 45 of Set 6 | port hardy
# Processing Record 46 of Set 6 | maniitsoq
# Processing Record 47 of Set 6 | broken hill
# Processing Record 48 of Set 6 | fairbanks
# Processing Record 49 of Set 6 | hagere selam
# Processing Record 50 of Set 6 | eydhafushi
# Processing Record 1 of Set 7 | prince rupert
# Processing Record 2 of Set 7 | port moresby
# Processing Record 3 of Set 7 | maningrida
# Processing Record 4 of Set 7 | flinders
# Processing Record 5 of Set 7 | newala
# Processing Record 6 of Set 7 | sao filipe
# Processing Record 7 of Set 7 | suntar
# Processing Record 8 of Set 7 | lahat
# Processing Record 9 of Set 7 | koping
# Processing Record 10 of Set 7 | kurri kurri
# Processing Record 11 of Set 7 | freeport
# Processing Record 12 of Set 7 | naryan-mar
# Processing Record 13 of Set 7 | bilma
# Processing Record 14 of Set 7 | umm bab
# Processing Record 15 of Set 7 | port lincoln
# Processing Record 16 of Set 7 | cabusao
# Processing Record 17 of Set 7 | emerald
# Processing Record 18 of Set 7 | svetlogorsk
# Processing Record 19 of Set 7 | poum
# Processing Record 20 of Set 7 | minturno
# Processing Record 21 of Set 7 | natal
# Processing Record 22 of Set 7 | ancud
# Processing Record 23 of Set 7 | kalengwa
# Processing Record 24 of Set 7 | luderitz
# Processing Record 25 of Set 7 | sundsvall
# Processing Record 26 of Set 7 | nelson bay
# Processing Record 27 of Set 7 | huarmey
# Processing Record 28 of Set 7 | baykit
# Processing Record 29 of Set 7 | taburi
# City not found. Skipping...
# Processing Record 30 of Set 7 | korla
# Processing Record 31 of Set 7 | peremyshl
# Processing Record 32 of Set 7 | bambous virieux
# Processing Record 33 of Set 7 | kieta
# Processing Record 34 of Set 7 | igrim
# Processing Record 35 of Set 7 | walvis bay
# Processing Record 36 of Set 7 | bagotville
# Processing Record 37 of Set 7 | gurskoye
# City not found. Skipping...
# Processing Record 38 of Set 7 | kasangulu
# Processing Record 39 of Set 7 | strelka
# Processing Record 40 of Set 7 | kaniv
# Processing Record 41 of Set 7 | knysna
# Processing Record 42 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 7 | kamiiso
# Processing Record 44 of Set 7 | bratsk
# Processing Record 45 of Set 7 | tocopilla
# Processing Record 46 of Set 7 | bousso
# Processing Record 47 of Set 7 | jacareacanga
# Processing Record 48 of Set 7 | gold coast
# Processing Record 49 of Set 7 | marsaxlokk
# Processing Record 50 of Set 7 | bethel
# Processing Record 1 of Set 8 | ambagarh chauki
# Processing Record 2 of Set 8 | manado
# Processing Record 3 of Set 8 | mersing
# Processing Record 4 of Set 8 | saint george
# Processing Record 5 of Set 8 | pasni
# Processing Record 6 of Set 8 | yerbogachen
# Processing Record 7 of Set 8 | chokurdakh
# Processing Record 8 of Set 8 | fortuna
# Processing Record 9 of Set 8 | sorland
# Processing Record 10 of Set 8 | mokolo
# Processing Record 11 of Set 8 | anloga
# Processing Record 12 of Set 8 | kurilsk
# Processing Record 13 of Set 8 | ambodifototra
# City not found. Skipping...
# Processing Record 14 of Set 8 | florianopolis
# Processing Record 15 of Set 8 | zhengjiatun
# Processing Record 16 of Set 8 | praia da vitoria
# Processing Record 17 of Set 8 | port keats
# Processing Record 18 of Set 8 | muroto
# Processing Record 19 of Set 8 | guerrero negro
# Processing Record 20 of Set 8 | margate
# Processing Record 21 of Set 8 | san matias
# Processing Record 22 of Set 8 | nabire
# Processing Record 23 of Set 8 | yatou
# Processing Record 24 of Set 8 | colares
# Processing Record 25 of Set 8 | domoni
# Processing Record 26 of Set 8 | yeppoon
# Processing Record 27 of Set 8 | chumikan
# Processing Record 28 of Set 8 | tromso
# Processing Record 29 of Set 8 | ketchikan
# Processing Record 30 of Set 8 | abilene
# Processing Record 31 of Set 8 | rafai
# Processing Record 32 of Set 8 | albi
# Processing Record 33 of Set 8 | vestmannaeyjar
# Processing Record 34 of Set 8 | xichang
# Processing Record 35 of Set 8 | chilliwack
# Processing Record 36 of Set 8 | aklavik
# Processing Record 37 of Set 8 | longyearbyen
# Processing Record 38 of Set 8 | la ronge
# Processing Record 39 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 40 of Set 8 | sanmenxia
# Processing Record 41 of Set 8 | gizycko
# Processing Record 42 of Set 8 | dasoguz
# Processing Record 43 of Set 8 | abu dhabi
# Processing Record 44 of Set 8 | haines junction
# Processing Record 45 of Set 8 | liku
# Processing Record 46 of Set 8 | coquimbo
# Processing Record 47 of Set 8 | nizwa
# Processing Record 48 of Set 8 | luanda
# Processing Record 49 of Set 8 | monster
# Processing Record 50 of Set 8 | khandyga
# Processing Record 1 of Set 9 | teya
# Processing Record 2 of Set 9 | tatarsk
# Processing Record 3 of Set 9 | yokadouma
# Processing Record 4 of Set 9 | vila velha
# Processing Record 5 of Set 9 | piacabucu
# Processing Record 6 of Set 9 | skibbereen
# Processing Record 7 of Set 9 | salamanca
# Processing Record 8 of Set 9 | roald
# Processing Record 9 of Set 9 | tessalit
# Processing Record 10 of Set 9 | maksatikha
# Processing Record 11 of Set 9 | cidreira
# Processing Record 12 of Set 9 | umm lajj
# Processing Record 13 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 9 | ambositra
# Processing Record 15 of Set 9 | celestun
# Processing Record 16 of Set 9 | tigil
# Processing Record 17 of Set 9 | coihaique
# Processing Record 18 of Set 9 | jaciara
# Processing Record 19 of Set 9 | albanel
# Processing Record 20 of Set 9 | vila franca do campo
# Processing Record 21 of Set 9 | george town
# Processing Record 22 of Set 9 | marfino
# Processing Record 23 of Set 9 | college
# Processing Record 24 of Set 9 | cuitzeo
# Processing Record 25 of Set 9 | parintins
# Processing Record 26 of Set 9 | touros
# Processing Record 27 of Set 9 | menongue
# Processing Record 28 of Set 9 | caibarien
# Processing Record 29 of Set 9 | cayenne
# Processing Record 30 of Set 9 | alofi
# Processing Record 31 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 32 of Set 9 | ohringen
# Processing Record 33 of Set 9 | ponta do sol
# Processing Record 34 of Set 9 | namatanai
# Processing Record 35 of Set 9 | alexandria
# Processing Record 36 of Set 9 | cockburn town
# Processing Record 37 of Set 9 | butaritari
# Processing Record 38 of Set 9 | kahramanmaras
# Processing Record 39 of Set 9 | siavonga
# Processing Record 40 of Set 9 | saint-augustin
# Processing Record 41 of Set 9 | nunkini
# Processing Record 42 of Set 9 | bathsheba
# Processing Record 43 of Set 9 | kaputa
# Processing Record 44 of Set 9 | jiwani
# Processing Record 45 of Set 9 | ciudad guayana
# Processing Record 46 of Set 9 | pisco
# Processing Record 47 of Set 9 | stokmarknes
# Processing Record 48 of Set 9 | lucapa
# Processing Record 49 of Set 9 | lompoc
# Processing Record 50 of Set 9 | shelburne
# Processing Record 1 of Set 10 | belmonte
# Processing Record 2 of Set 10 | lalibela
# Processing Record 3 of Set 10 | kaeo
# Processing Record 4 of Set 10 | inta
# Processing Record 5 of Set 10 | pandan
# Processing Record 6 of Set 10 | pristina
# Processing Record 7 of Set 10 | hashtgerd
# Processing Record 8 of Set 10 | sisimiut
# Processing Record 9 of Set 10 | karauli
# Processing Record 10 of Set 10 | kuryk
# Processing Record 11 of Set 10 | lahaina
# Processing Record 12 of Set 10 | karamay
# City not found. Skipping...
# Processing Record 13 of Set 10 | humaita
# Processing Record 14 of Set 10 | gangakher
# Processing Record 15 of Set 10 | egvekinot
# Processing Record 16 of Set 10 | hambantota
# Processing Record 17 of Set 10 | mvuma
# Processing Record 18 of Set 10 | shenjiamen
# Processing Record 19 of Set 10 | puro
# Processing Record 20 of Set 10 | abnub
# Processing Record 21 of Set 10 | champerico
# Processing Record 22 of Set 10 | srednekolymsk
# Processing Record 23 of Set 10 | leningradskiy
# Processing Record 24 of Set 10 | ayan
# Processing Record 25 of Set 10 | gulmarg
# Processing Record 26 of Set 10 | shetpe
# Processing Record 27 of Set 10 | korhogo
# Processing Record 28 of Set 10 | qui nhon
# Processing Record 29 of Set 10 | nampa
# Processing Record 30 of Set 10 | gumushane
# City not found. Skipping...
# Processing Record 31 of Set 10 | greeneville
# Processing Record 32 of Set 10 | galesong
# Processing Record 33 of Set 10 | ntoum
# Processing Record 34 of Set 10 | benemerito de las americas
# Processing Record 35 of Set 10 | forssa
# Processing Record 36 of Set 10 | durant
# Processing Record 37 of Set 10 | ahipara
# Processing Record 38 of Set 10 | raymond
# Processing Record 39 of Set 10 | kysyl-syr
# Processing Record 40 of Set 10 | makungu
# Processing Record 41 of Set 10 | varzea grande
# Processing Record 42 of Set 10 | anar darreh
# City not found. Skipping...
# Processing Record 43 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 44 of Set 10 | ratnagiri
# Processing Record 45 of Set 10 | kirakira
# Processing Record 46 of Set 10 | gweta
# Processing Record 47 of Set 10 | makakilo city
# Processing Record 48 of Set 10 | cabra
# Processing Record 49 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 50 of Set 10 | ulladulla
# Processing Record 1 of Set 11 | bodden town
# Processing Record 2 of Set 11 | yulara
# Processing Record 3 of Set 11 | te anau
# Processing Record 4 of Set 11 | mount pleasant
# Processing Record 5 of Set 11 | tokur
# Processing Record 6 of Set 11 | ploufragan
# Processing Record 7 of Set 11 | tunduru
# City not found. Skipping...
# Processing Record 8 of Set 11 | nyagan
# Processing Record 9 of Set 11 | lungi
# Processing Record 10 of Set 11 | port-cartier
# Processing Record 11 of Set 11 | gorontalo
# Processing Record 12 of Set 11 | manacapuru
# Processing Record 13 of Set 11 | skjaerhollen
# City not found. Skipping...
# Processing Record 14 of Set 11 | buchanan
# Processing Record 15 of Set 11 | jetpur
# Processing Record 16 of Set 11 | ambunti
# Processing Record 17 of Set 11 | jacksonville
# Processing Record 18 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 19 of Set 11 | gushikawa
# Processing Record 20 of Set 11 | cap malheureux
# Processing Record 21 of Set 11 | jiuquan
# Processing Record 22 of Set 11 | manjacaze
# Processing Record 23 of Set 11 | vardo
# Processing Record 24 of Set 11 | pimenta bueno
# Processing Record 25 of Set 11 | tadine
# Processing Record 26 of Set 11 | san ignacio
# Processing Record 27 of Set 11 | kushima
# Processing Record 28 of Set 11 | barentu
# Processing Record 29 of Set 11 | reconquista
# Processing Record 30 of Set 11 | torzhok
# Processing Record 31 of Set 11 | tuggurt
# City not found. Skipping...
# Processing Record 32 of Set 11 | kavieng
# Processing Record 33 of Set 11 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 34 of Set 11 | sungurlu
# Processing Record 35 of Set 11 | coolum beach
# Processing Record 36 of Set 11 | suixi
# Processing Record 37 of Set 11 | gewane
# Processing Record 38 of Set 11 | kallithea
# Processing Record 39 of Set 11 | lakes entrance
# Processing Record 40 of Set 11 | tahoua
# Processing Record 41 of Set 11 | palora
# Processing Record 42 of Set 11 | gornopravdinsk
# Processing Record 43 of Set 11 | takapau
# Processing Record 44 of Set 11 | sayyan
# Processing Record 45 of Set 11 | pundaguitan
# Processing Record 46 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 11 | tommot
# Processing Record 48 of Set 11 | klaksvik
# Processing Record 49 of Set 11 | husavik
# Processing Record 50 of Set 11 | belaya gora
# Processing Record 1 of Set 12 | puerto ayacucho
# Processing Record 2 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 12 | viedma
# Processing Record 4 of Set 12 | carire
# Processing Record 5 of Set 12 | zorgo
# Processing Record 6 of Set 12 | mitsamiouli
# Processing Record 7 of Set 12 | bandar-e lengeh
# Processing Record 8 of Set 12 | duku
# Processing Record 9 of Set 12 | mitu
# Processing Record 10 of Set 12 | kununurra
# Processing Record 11 of Set 12 | bonavista
# Processing Record 12 of Set 12 | camacha
# Processing Record 13 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 12 | javanrud
# Processing Record 15 of Set 12 | eureka
# Processing Record 16 of Set 12 | lypova dolyna
# Processing Record 17 of Set 12 | azimur
# City not found. Skipping...
# Processing Record 18 of Set 12 | xuchang
# Processing Record 19 of Set 12 | gravdal
# Processing Record 20 of Set 12 | krasnovishersk
# Processing Record 21 of Set 12 | padang
# Processing Record 22 of Set 12 | japura
# Processing Record 23 of Set 12 | quatre cocos
# Processing Record 24 of Set 12 | byron bay
# Processing Record 25 of Set 12 | illapel
# Processing Record 26 of Set 12 | simpang
# Processing Record 27 of Set 12 | dolores
# Processing Record 28 of Set 12 | baillif
# Processing Record 29 of Set 12 | kayan
# Processing Record 30 of Set 12 | caxito
# Processing Record 31 of Set 12 | miyako
# Processing Record 32 of Set 12 | lata
# Processing Record 33 of Set 12 | la asuncion
# Processing Record 34 of Set 12 | preston
# Processing Record 35 of Set 12 | jibuti
# Processing Record 36 of Set 12 | mangrol
# Processing Record 37 of Set 12 | maracas
# Processing Record 38 of Set 12 | ipojuca
# Processing Record 39 of Set 12 | dandong
# Processing Record 40 of Set 12 | kissidougou
# Processing Record 41 of Set 12 | chake chake
# Processing Record 42 of Set 12 | udupi
# Processing Record 43 of Set 12 | salgotarjan
# Processing Record 44 of Set 12 | xining
# Processing Record 45 of Set 12 | ouadda
# Processing Record 46 of Set 12 | madison
# Processing Record 47 of Set 12 | bac lieu
# Processing Record 48 of Set 12 | juneau
# Processing Record 49 of Set 12 | la seyne-sur-mer
# Processing Record 50 of Set 12 | samur
# Processing Record 1 of Set 13 | timmins
# Processing Record 2 of Set 13 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 3 of Set 13 | chifeng
# Processing Record 4 of Set 13 | lerwick
# Processing Record 5 of Set 13 | mezen
# Processing Record 6 of Set 13 | mareeba
# Processing Record 7 of Set 13 | santa maria
# Processing Record 8 of Set 13 | peniche
# Processing Record 9 of Set 13 | puksoozero
# Processing Record 10 of Set 13 | svetlopolyansk
# Processing Record 11 of Set 13 | yar-sale
# Processing Record 12 of Set 13 | inuvik
# Processing Record 13 of Set 13 | gusau
# Processing Record 14 of Set 13 | puerto escondido
# Processing Record 15 of Set 13 | coracora
# Processing Record 16 of Set 13 | girvan
# Processing Record 17 of Set 13 | hun
# Processing Record 18 of Set 13 | samarai
# Processing Record 19 of Set 13 | banmo
# City not found. Skipping...
# Processing Record 20 of Set 13 | pangkalanbuun
# Processing Record 21 of Set 13 | marystown
# Processing Record 22 of Set 13 | grants
# Processing Record 23 of Set 13 | mehamn
# Processing Record 24 of Set 13 | duvan
# Processing Record 25 of Set 13 | vaitape
# Processing Record 26 of Set 13 | kokopo
# Processing Record 27 of Set 13 | managua
# Processing Record 28 of Set 13 | nouadhibou
# Processing Record 29 of Set 13 | tongzi
# Processing Record 30 of Set 13 | saint-louis
# Processing Record 31 of Set 13 | omsukchan
# Processing Record 32 of Set 13 | lesnica
# Processing Record 33 of Set 13 | micheweni
# Processing Record 34 of Set 13 | floriano
# Processing Record 35 of Set 13 | syasstroy
# Processing Record 36 of Set 13 | selfoss
# Processing Record 37 of Set 13 | moshenskoye
# Processing Record 38 of Set 13 | grand gaube
# Processing Record 39 of Set 13 | merauke
# Processing Record 40 of Set 13 | vyshhorod
# Processing Record 41 of Set 13 | artyk
# City not found. Skipping...
# Processing Record 42 of Set 13 | rio gallegos
# Processing Record 43 of Set 13 | pacific grove
# Processing Record 44 of Set 13 | perene
# Processing Record 45 of Set 13 | lasa
# Processing Record 46 of Set 13 | da nang
# Processing Record 47 of Set 13 | puerto narino
# Processing Record 48 of Set 13 | olkhovatka
# Processing Record 49 of Set 13 | faridkot
# Processing Record 50 of Set 13 | paita
# Processing Record 1 of Set 14 | havoysund
# Processing Record 2 of Set 14 | saint anthony
# Processing Record 3 of Set 14 | povenets
# Processing Record 4 of Set 14 | ocos
# Processing Record 5 of Set 14 | cap-aux-meules
# Processing Record 6 of Set 14 | nassau
# Processing Record 7 of Set 14 | belyy yar
# Processing Record 8 of Set 14 | sydney
# Processing Record 9 of Set 14 | tkvarcheli
# City not found. Skipping...
# Processing Record 10 of Set 14 | nizhniy tsasuchey
# Processing Record 11 of Set 14 | ayapa
# Processing Record 12 of Set 14 | qaqortoq
# Processing Record 13 of Set 14 | krasnoselkup
# Processing Record 14 of Set 14 | ottawa
# Processing Record 15 of Set 14 | syamzha
# Processing Record 16 of Set 14 | luau
# Processing Record 17 of Set 14 | axim
# Processing Record 18 of Set 14 | palmer
# Processing Record 19 of Set 14 | chekhov
# Processing Record 20 of Set 14 | manyana
# Processing Record 21 of Set 14 | evensk
# Processing Record 22 of Set 14 | dehloran
# Processing Record 23 of Set 14 | akyab
# Processing Record 24 of Set 14 | atagay
# Processing Record 25 of Set 14 | balimo
# City not found. Skipping...
# Processing Record 26 of Set 14 | brae
# Processing Record 27 of Set 14 | ulcinj
# Processing Record 28 of Set 14 | kunjah
# Processing Record 29 of Set 14 | kangaatsiaq
# Processing Record 30 of Set 14 | kodinsk
# Processing Record 31 of Set 14 | aras
# Processing Record 32 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 33 of Set 14 | gidam
# Processing Record 34 of Set 14 | barcelos
# Processing Record 35 of Set 14 | teguldet
# Processing Record 36 of Set 14 | narrabri
# Processing Record 37 of Set 14 | ganzhou
# Processing Record 38 of Set 14 | caudebec-les-elbeuf
# Processing Record 39 of Set 14 | moron
# Processing Record 40 of Set 14 | antofagasta
# Processing Record 41 of Set 14 | tateyama
# Processing Record 42 of Set 14 | safaga
# Processing Record 43 of Set 14 | sur
# Processing Record 44 of Set 14 | garissa
# Processing Record 45 of Set 14 | banjar
# Processing Record 46 of Set 14 | mount gambier
# Processing Record 47 of Set 14 | westport
# Processing Record 48 of Set 14 | saint-francois
# Processing Record 49 of Set 14 | domanivka
# Processing Record 50 of Set 14 | parrita
# Processing Record 1 of Set 15 | songjianghe
# Processing Record 2 of Set 15 | alta floresta
# Processing Record 3 of Set 15 | bristol
# Processing Record 4 of Set 15 | ukiah
# Processing Record 5 of Set 15 | blythe
# Processing Record 6 of Set 15 | tchaourou
# Processing Record 7 of Set 15 | whitehorse
# Processing Record 8 of Set 15 | ishikawa
# Processing Record 9 of Set 15 | bitung
# Processing Record 10 of Set 15 | perivolion
# Processing Record 11 of Set 15 | otane
# Processing Record 12 of Set 15 | katete
# Processing Record 13 of Set 15 | nemuro
# Processing Record 14 of Set 15 | savannah bight
# Processing Record 15 of Set 15 | geresk
# City not found. Skipping...
# Processing Record 16 of Set 15 | bell ville
# Processing Record 17 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 18 of Set 15 | lufilufi
# Processing Record 19 of Set 15 | divnomorskoye
# Processing Record 20 of Set 15 | rudbar
# Processing Record 21 of Set 15 | kumluca
# Processing Record 22 of Set 15 | svetlaya
# Processing Record 23 of Set 15 | uspenka
# Processing Record 24 of Set 15 | tongliao
# Processing Record 25 of Set 15 | urumqi
# Processing Record 26 of Set 15 | robertsport
# Processing Record 27 of Set 15 | baley
# Processing Record 28 of Set 15 | anchorage
# Processing Record 29 of Set 15 | puquio
# Processing Record 30 of Set 15 | kudahuvadhoo
# Processing Record 31 of Set 15 | mayor pablo lagerenza
# Processing Record 32 of Set 15 | chumphon
# Processing Record 33 of Set 15 | hat yai
# Processing Record 34 of Set 15 | bilibino
# Processing Record 35 of Set 15 | banda aceh
# Processing Record 36 of Set 15 | russell
# Processing Record 37 of Set 15 | severo-yeniseyskiy
# Processing Record 38 of Set 15 | sunrise manor
# Processing Record 39 of Set 15 | weilerswist
# Processing Record 40 of Set 15 | phangnga
# Processing Record 41 of Set 15 | asau
# Processing Record 42 of Set 15 | caravelas
# Processing Record 43 of Set 15 | palana
# Processing Record 44 of Set 15 | chesterfield
# Processing Record 45 of Set 15 | karpogory
# Processing Record 46 of Set 15 | northam
# Processing Record 47 of Set 15 | ilhabela
# Processing Record 48 of Set 15 | oban
# Processing Record 49 of Set 15 | dianopolis
# City not found. Skipping...
# Processing Record 50 of Set 15 | raton
# Processing Record 1 of Set 16 | kiunga
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 695

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Albany  42.6001  -73.9662     49.41        78         100
# 1  Severo-Kurilsk  50.6789  156.1250     53.46        72          98
# 2         Rikitea -23.1203 -134.9692     71.35        66         100
# 3        San Luis -33.2950  -66.3356     68.11        31           1
# 4    Puerto Ayora  -0.7393  -90.3518     65.55        94          41
# 5        Bengkulu  -3.8004  102.2655     77.76        86         100
# 6           Kyren  51.6828  102.1408     30.85        51          67
# 7     Meadow Lake  34.8014 -106.5436     68.11        84          56
# 8     Port-Gentil  -0.7193    8.7815     77.50        83         100
# 9           Vaini -21.2000 -175.2000     82.56        69          75
#
#    Wind Speed Country Current Description
# 0        1.88      US     overcast clouds
# 1       15.28      RU     overcast clouds
# 2       19.53      PF     overcast clouds
# 3       12.68      AR           clear sky
# 4        4.00      EC    scattered clouds
# 5        3.20      ID     overcast clouds
# 6        0.83      RU       broken clouds
# 7       12.55      US          light rain
# 8       11.48      GA     overcast clouds
# 9       14.97      TO       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Albany      US  42.6001  -73.9662     49.41        78
# 1    Severo-Kurilsk      RU  50.6789  156.1250     53.46        72
# 2           Rikitea      PF -23.1203 -134.9692     71.35        66
# 3          San Luis      AR -33.2950  -66.3356     68.11        31
# 4      Puerto Ayora      EC  -0.7393  -90.3518     65.55        94
# ..              ...     ...      ...       ...       ...       ...
# 690         Northam      GB  51.0333   -4.2167     57.38        90
# 691        Ilhabela      BR -23.7781  -45.3581     67.32        92
# 692            Oban      GB  56.4127   -5.4706     60.39        88
# 693           Raton      US  36.9034 -104.4391     53.06        93
# 694          Kiunga      PG  -6.1219  141.2906     90.25        57
#
#      Cloudiness  Wind Speed Current Description
# 0           100        1.88     overcast clouds
# 1            98       15.28     overcast clouds
# 2           100       19.53     overcast clouds
# 3             1       12.68           clear sky
# 4            41        4.00    scattered clouds
# ..          ...         ...                 ...
# 690          52       13.00       broken clouds
# 691         100        5.41     overcast clouds
# 692         100       21.94          light rain
# 693          40        5.75    scattered clouds
# 694          93        3.98     overcast clouds
#
# [695 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
WeatherPy_Database = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(WeatherPy_Database, index_label="WeatherPy_Database")
